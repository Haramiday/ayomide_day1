# %%
import pandas as pd

# %%
column = ['bkblk','bknwy','bkon8','bkona','bkspr','bkxbq','bkxcr','bkxwp','blxwp','bxqsq','cntxt','dsopp','dwipd',\
         'hdchk','katri','mulch','qxmsq','r2ar8','reskd','reskr','rimmx','rkxwp','rxmsq','simpl','skach','skewr','skrxp',\
         'spcop','stlmt','thrsk','wkcti','wkna8','wknck','wkovl','wkpos','wtoeg','target']
chess = pd.read_csv("kr-vs-kp1.csv",names=column)
#chess.set_columns(column)

# %%
chess.head()
# Out:
#   bkblk bknwy bkon8 bkona bkspr bkxbq bkxcr bkxwp blxwp bxqsq  ...   spcop  \
# 0     f     f     f     f     f     f     f     f     f     f  ...       f
# 1     f     f     f     f     t     f     f     f     f     f  ...       f
# 2     f     f     f     f     t     f     t     f     f     f  ...       f
# 3     f     f     f     f     f     f     f     f     t     f  ...       f
# 4     f     f     f     f     f     f     f     f     f     f  ...       f
#
#   stlmt thrsk wkcti wkna8 wknck wkovl wkpos wtoeg target
# 0     f     f     f     f     f     t     t     n    won
# 1     f     f     f     f     f     t     t     n    won
# 2     f     f     f     f     f     t     t     n    won
# 3     f     f     f     f     f     t     t     n    won
# 4     f     f     f     f     f     t     t     n    won
#
# [5 rows x 37 columns]

# %%
#using the train test split 70:30
len_chess = len(chess)
test_ratio = round((70/100)*len_chess)
train_ratio = round((30/100)*len_chess)

train_set = chess[-train_ratio:]
test_set = chess[:test_ratio]

# %%
#preprocessing the categorical data
pre_data=pd.get_dummies(chess).head()

# %%
# #choosing 18 best feature for training
# from sklearn.feature_selection import SelectKBest
# from sklearn.feature_selection import mutual_info_classif
# x=pre_data.iloc[:,:-2]
# y=pre_data.iloc[:,-2:]

# best_features = SelectKBest(score_func=mutual_info_classif, k='all')
# fit = best_features.fit(x,y)
# fit.scores_
